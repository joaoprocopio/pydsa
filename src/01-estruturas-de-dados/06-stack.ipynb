# %% [markdown]
# # stack
#
# LIFO — last-in; first-out.
#
# <img src="./static/stack.jpg" width="500" />
#
# ## ou caso você prefira um exemplo não-abstrato
#
# <img src="./static/stack.png" width="500" />
