# %% [markdown]
# # b-tree
#
# é uma árvore auto-balancéavel com as seguintes regras:
# 1. você define o número de chaves por nó
# 2. você define a profundida máxima da árvore
# 3. todos os nós leaf estão no mesmo nível de altura
